# %%
#!/usr/bin/env python
#
# Very basic example of using Python 3 and IMAP to iterate over emails in a
# gmail folder/label.  This code is released into the public domain.
#
# This script is example code from this blog post:
# http://www.voidynullness.net/blog/2013/07/25/gmail-email-with-python-via-imap/
#
# This is an updated version of the original -- modified to work with Python 3.4.
#
import sys
import imaplib
import getpass
import email
import email.header
import datetime

EMAIL_ACCOUNT = "cdhimmel@gmail.com"

# Use 'INBOX' to read inbox.  Note that whatever folder is specified, 
# after successfully running this script all emails in that folder 
# will be marked as read.
EMAIL_FOLDER = "INBOX"

# %%
def process_mailbox(M):
    """
    Do something with emails messages in the folder.  
    For the sake of this example, print some headers.
    """

    rv, data = M.search(None, "ALL")
    if rv != 'OK':
        print("No messages found!")
        return

    for num in data[0].split():
        rv, data = M.fetch(num, '(RFC822)')
        if rv != 'OK':
            print("ERROR getting message", num)
            return

        msg = email.message_from_bytes(data[0][1])
        hdr = email.header.make_header(email.header.decode_header(msg['Subject']))
        subject = str(hdr)
        print('Message %s: %s' % (num, subject))
        print('Raw Date:', msg['Date'])
        # Now convert to local date-time
        date_tuple = email.utils.parsedate_tz(msg['Date'])
        if date_tuple:
            local_date = datetime.datetime.fromtimestamp(
                email.utils.mktime_tz(date_tuple))
            print ("Local Date:", \
                local_date.strftime("%a, %d %b %Y %H:%M:%S"))

# %%
M = imaplib.IMAP4_SSL('imap.gmail.com')

try:
    rv, data = M.login(EMAIL_ACCOUNT, getpass.getpass())
except imaplib.IMAP4.error:
    print ("LOGIN FAILED!!! ")
    sys.exit(1)

print(rv, data)
# Out:
# ········
# OK [b'cdhimmel@gmail.com authenticated (Success)']

# %%
rv, mailboxes = M.list()
if rv == 'OK':
    print("Mailboxes:")
    print(mailboxes)

rv, data = M.select(EMAIL_FOLDER)
if rv == 'OK':
    print("Processing mailbox...\n")
    process_mailbox(M)
    M.close()
else:
    print("ERROR: Unable to open mailbox ", rv)

M.logout()
# Out:
# Mailboxes:
# [b'(\\HasNoChildren) "/" "624"', b'(\\HasNoChildren) "/" "Apt"', b'(\\HasNoChildren) "/" "Drafts"', b'(\\HasChildren) "/" "Financial"', b'(\\HasNoChildren) "/" "Financial/Flex"', b'(\\HasNoChildren) "/" "Financial/Insurance"', b'(\\HasNoChildren) "/" "Financial/Receipts"', b'(\\HasNoChildren) "/" "Financial/Tax"', b'(\\HasNoChildren) "/" "Financial/credit"', b'(\\HasNoChildren) "/" "Friends"', b'(\\HasNoChildren) "/" "INBOX"', b'(\\HasNoChildren) "/" "Kate"', b'(\\HasNoChildren) "/" "NN"', b'(\\HasNoChildren) "/" "Nathan"', b'(\\HasNoChildren) "/" "Notes"', b'(\\HasNoChildren) "/" "Outbox"', b'(\\HasNoChildren) "/" "Running"', b'(\\HasNoChildren) "/" "Sent Messages"', b'(\\HasNoChildren) "/" "Stock pricing"', b'(\\HasNoChildren) "/" "Work"', b'(\\HasChildren \\Noselect) "/" "[Gmail]"', b'(\\All \\HasNoChildren) "/" "[Gmail]/All Mail"', b'(\\HasNoChildren) "/" "[Gmail]/Chats"', b'(\\Drafts \\HasNoChildren) "/" "[Gmail]/Drafts"', b'(\\HasNoChildren \\Important) "/" "[Gmail]/Important"', b'(\\HasNoChildren \\Sent) "/" "[Gmail]/Sent Mail"', b'(\\HasNoChildren \\Junk) "/" "[Gmail]/Spam"', b'(\\Flagged \\HasNoChildren) "/" "[Gmail]/Starred"', b'(\\HasNoChildren \\Trash) "/" "[Gmail]/Trash"']
# Processing mailbox...
#
# Message b'1': Yo bubba!
# Raw Date: Mon, 7 Oct 2013 05:33:12 -0400 (EDT)
# Local Date: Mon, 07 Oct 2013 02:33:12
# Message b'2': Re: Fwd: Yo bubba!
# Raw Date: Mon, 7 Oct 2013 09:21:40 -0700
# Local Date: Mon, 07 Oct 2013 09:21:40
# Message b'3': Fwd: Yo bubba!
# Raw Date: Mon, 11 Nov 2013 14:32:22 -0800
# Local Date: Mon, 11 Nov 2013 14:32:22
# Message b'4': Delivery Status Notification (Failure)
# Raw Date: Wed, 13 Nov 2013 16:35:19 +0000
# Local Date: Wed, 13 Nov 2013 08:35:19
# Message b'5': Re: Yo bubba!
# Raw Date: Tue, 26 Nov 2013 18:13:39 -0500 (EST)
# Local Date: Tue, 26 Nov 2013 15:13:39
# Message b'6': Welcome to the Crossfit of the Awesome!
# Raw Date: Thu, 23 Jan 2014 07:59:43 -0700
# Local Date: Thu, 23 Jan 2014 06:59:43
# Message b'7': New Tamalpa Member
# Raw Date: Wed, 29 Jan 2014 21:46:44 -0800
# Local Date: Wed, 29 Jan 2014 21:46:44
# Message b'8': Greetings from YogaWorks
# Raw Date: Wed, 5 Feb 2014 15:02:17 -0800
# Local Date: Wed, 05 Feb 2014 15:02:17
# Message b'9': RE: 2014 Fairfield - Suisun Running Festival Signup Now!
# Raw Date: Fri, 7 Feb 2014 17:47:37 +0000
# Local Date: Fri, 07 Feb 2014 09:47:37
# Message b'10': RE: 2014 Fairfield - Suisun Running Festival Signup Now!
# Raw Date: Fri, 7 Feb 2014 17:48:14 +0000
# Local Date: Fri, 07 Feb 2014 09:48:14
# Message b'11': RE: 2014 Fairfield - Suisun Running Festival Signup Now!
# Raw Date: Fri, 7 Feb 2014 18:23:41 +0000
# Local Date: Fri, 07 Feb 2014 10:23:41
# Message b'12': RE: 2014 Fairfield - Suisun Running Festival Signup Now!
# Raw Date: Sat, 8 Feb 2014 00:57:44 +0000
# Local Date: Fri, 07 Feb 2014 16:57:44
# Message b'13': Rhodes Race 5K - registration is open
# Raw Date: Sun, 9 Feb 2014 15:53:50 -0800
# Local Date: Sun, 09 Feb 2014 15:53:50
# Message b'14': Contract to Hire for RPG Opportunity
# Raw Date: Wed, 12 Feb 2014 17:37:43 -0500
# Local Date: Wed, 12 Feb 2014 14:37:43
# Message b'15': [Fwd: Make Appointment]
# Raw Date: Mon, 17 Feb 2014 20:28:48 -0500
# Local Date: Mon, 17 Feb 2014 17:28:48
# Message b'16': Reservation Confirmation for July 1, 2014
# Raw Date: Wed, 19 Feb 2014 15:12:14 -0700 (MST)
# Local Date: Fri, 28 Mar 2014 08:14:44
# Message b'54': Re: Ride to WFTW
# Raw Date: Fri, 28 Mar 2014 11:32:25 -0400
# Local Date: Fri, 28 Mar 2014 08:32:25
# Message b'55': Fwd: Retained Search - Director of IT
# Raw Date: Fri, 28 Mar 2014 11:51:52 -0700
# Local Date: Fri, 28 Mar 2014 11:51:52
# Message b'56': options
# Raw Date: Fri, 28 Mar 2014 19:37:18 -0700 (PDT)
# Local Date: Fri, 28 Mar 2014 19:37:18
# Message b'57': Re: options
# Raw Date: Sat, 29 Mar 2014 13:51:21 -0700 (PDT)
# Local Date: Sat, 29 Mar 2014 13:51:21
# Message b'58': Pac Champs - Day 1 Results
# Raw Date: Sat, 29 Mar 2014 14:04:48 -0700 (PDT)
# Local Date: Sat, 29 Mar 2014 14:04:48
# Message b'59': Champs - Day 2
# Raw Date: Sat, 29 Mar 2014 20:59:24 -0700 (PDT)
# Local Date: Sat, 29 Mar 2014 20:59:24
# Message b'60': Fwd: Rhodes Race 5K - two weeks away
# Raw Date: Sun, 30 Mar 2014 08:59:27 -0700
# Local Date: Sun, 30 Mar 2014 08:59:27
# Message b'61': Champs � Day 3 / DRY LAND
# Raw Date: Sun, 30 Mar 2014 22:35:52 -0700 (PDT)
# Local Date: Sun, 30 Mar 2014 22:35:52
# Message b'62': Would Love Your Help & Support
# Raw Date: Mon, 31 Mar 2014 15:56:50 -0400
# Local Date: Mon, 31 Mar 2014 12:56:50
# Message b'63': G37 Special-Today Only!
# Raw Date: Mon, 31 Mar 2014 17:14:04 -0500
# Local Date: Mon, 31 Mar 2014 15:14:04
# Message b'64': Thinking about Half-Ironman Distance Races? We want to know!
# Raw Date: Mon, 31 Mar 2014 21:23:50 -0700
# Local Date: Mon, 31 Mar 2014 21:23:50
# Message b'65': Re: Thinking about Half-Ironman Distance Races? We want to know!
# Raw Date: Mon, 31 Mar 2014 21:32:27 -0700
# Local Date: Mon, 31 Mar 2014 21:32:27
# Message b'66': bike fitting and testing
# Raw Date: Tue, 1 Apr 2014 07:44:27 -0700
# Local Date: Tue, 01 Apr 2014 07:44:27
# Message b'67': NO COM
# Raw Date: Tue, 1 Apr 2014 10:22:53 -0700 (PDT)
# Local Date: Tue, 01 Apr 2014 10:22:53
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-bfeeaa84d4fa> in <module>
#       7 if rv == 'OK':
#       8     print("Processing mailbox...\n")
# ----> 9     process_mailbox(M)
#      10     M.close()
#      11 else:
#
# <ipython-input-3-86208935601e> in process_mailbox(M)
#      17
#      18         msg = email.message_from_bytes(data[0][1])
# ---> 19         hdr = email.header.make_header(email.header.decode_header(msg['Subject']))
#      20         subject = str(hdr)
#      21         print('Message %s: %s' % (num, subject))
#
# C:\ProgramData\Anaconda3\envs\tensorflow_env\lib\email\header.py in decode_header(header)
#      78                     for string, charset in header._chunks]
#      79     # If no encoding, just return the header with no charset.
# ---> 80     if not ecre.search(header):
#      81         return [(header, None)]
#      82     # First step is to parse all the encoded parts into triplets of the form
#
# TypeError: expected string or bytes-like object
